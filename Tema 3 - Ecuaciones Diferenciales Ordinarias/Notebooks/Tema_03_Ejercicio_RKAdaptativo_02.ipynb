# %% [markdown]
# # Segundo ejercicio con RKAdaptativo.
#
# Resuelve el siguiente problema que es moderadamente rígido con el método Runge-Kutta Adaptativo:
#
# $$
# \begin{align*}
# y^{\prime \prime} = - \dfrac{19}{4} \, y - 10 \, y^{\prime} \hspace{1.5cm} y (0) = -9, \hspace{0.5cm} y^{\prime} (0) = 0
# \end{align*}
# $$
#
# de $x = 0$ a $10$. **¿Qué tan moderadamente rígido es en realidad?**
#
# Gráfica los resultados, es decir $y$ e $y^{\prime}$

# %% [markdown]
# ## Consideración.
#
# Debido a que usamos un método adaptativo, no hay necesidad de preocuparse por el rango estable de $h$
#
# Siempre que especifiquemos una tolerancia razonable para el error por paso (en este caso, el valor predeterminado $10^{−6}$ está bien), el algoritmo encontrará el tamaño de paso apropiado.

# %% [markdown]
# ## Función F con el sistema de EDO1.
#
# Como ya hemos venido comentando que antes de pasar al código, escribe en tu cuaderno la función $\mathbf{F} (x, \mathbf{y})$ para que entonces en la implementación de la solución, te sea más fácil seguir con el algoritmo.
#
# Aquí anota con markdown la función $\mathbf{F} (x, \mathbf{y})$, puedes ocupar de algún notebook previo, la manera de escribirlo y que se vea como tipo $\LaTeX$.

# %%
#Aqui va la llamada a las librerías


#Aquí va la función F
def F(x, y):
    pass

# Aquí van varios elementos específicos del dominio, condiciones iniciales y el paso de integración


# Aquí va la llamada a la función RKAdapativo


# Aquí va la rutina de graficación

# %% [markdown]
# # Discusión.
#
# 1. Los resultados están de acuerdo con la solución analítica. **(¿Cuál es esa solución ''exacta''?)**
# 2. Las gráficas de $y$ e $y^{\prime}$ se muestran en la siguiente figura.
#
# ![Solucion Ejercicio RKAdaptativo 02](attachment:Ejercicio_RKAdaptativo_Ejercicio_02.png)
#
# 3. Tomemos en cuenta la alta densidad de puntos cerca de $x = 0$ donde $y^{\prime}$ cambia rápidamente.
# 4. A medida que la curva $y^{\prime}$ se suaviza, la distancia entre los puntos aumenta.
