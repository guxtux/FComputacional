# %% [markdown]
# # Ejercicio. Sistema de 3 masas acopladas.
#
# En la figura se muestra un sistema de tres masas acopladas mediante resortes y amortiguadores.
#
#
# Los desplazamientos de estas tres masas satisfacen las ecuaciones dadas por:
# $$
# \begin{align*}
# M_{1} \: y^{\prime \prime}{1} + B_{1} \: y^{\prime}_{1} + K_{1} \: y_{1} - B_{1} \: y^{\prime}_{2} - K_{2} \: y_{2} & = F_{1}(t) \\
# -B_{1} \: y^{\prime}_{1} - K_{1} \: y_{1} + M_{2} \:  y^{\prime \prime}_{2} + B_{1} \: y^{\prime}_{2} + (K_{1} + K_{2}) \: y_{2} - K_{2} \: y_{3} & = 0 \\
# - K_{2} \: y_{2} + M_{3} \: y^{\prime \prime}_{3} + B_{2} \: y^{\prime}_{3} + (K_{2} + K_{3})  \: y_{3} & =  F_{3}(t)
# \end{align*}
# $$
#
# Las constantes y condiciones iniciales son:
#
# 1. $K_{1} = K_{2} = K_{3} = 1$ constantes de los resortes, $kg \, m /s^{2}$)
# 2. $M_{1} = M_{2} = M_{3} = 1$ masa, $kg$
# 3. $F_{1}(t) = 1, F_{3}(t) = 0$ Fuerza, $N$
# 4. $B_{1} = B_{2} = 0.1$ coeficientes de amortiguamiento $kg / s)$
# 5. $y_{1} (0) = y_{1}^{\prime} (0) = y_{2} (0) = y_{2}^{\prime} (0) = y_{3} (0) = y_{3}^{\prime} (0) = 0$ condiciones iniciales.

# %% [markdown]
# # Problema a resolver.
#
# Resuelve el sistema para determinar la posición $y_{i}$ de cada masa en $0 \leq t \leq 60$ segundos, elabora una gráfica con las tres trayectorias.

# %% [markdown]
# # Antes de proponer un código.
#
# Necesitamos manejar el sistema de 3 EDO2, de tal manera que podamos representar un sistema de 6 EDO1, entonces consideremos lo siguiente:
#
# Si definimos:
#
# $$
# \begin{align*}
# y_{4} = y_{1}^{\prime}, \hspace{1cm} y_{5} = y_{2}^{\prime}, \hspace{1cm} y_{6} = y_{3}^{\prime}
# \end{align*}
# $$
#
# Así, la ecuación inicial se escribirá como un conjunto de seis EDO de primer orden, de la siguiente manera:
#
# **Aquí hay que escribir el sistema de 6 EDO1**

# %%
# %matplotlib inline

from numpy import zeros, array, linspace
from scipy.integrate import odeint
import matplotlib.pyplot as plt

def F(y, t):
    pass
    
    return F

# Se completa el código con lo necesario para utilizar la función odeint


# Se completa la rutina de graficación

# %% [markdown]
# # Solución gráfica.
#
# Luego de haber completado la información y la rutina de graficación, se obtiene una gráfica con la trayectoria de cada una de las tres masas acopladas durante el tiempo indicado.
#
# ![Solución sistema de masas acopladas](attachment:plot_Ejercicio_odeint_04_Masas_Acopladas.png)
