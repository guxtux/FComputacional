# %% [markdown]
# # Enunciado del ejercicio con el método predictor-corrector de Euler.
#
# El récord mundial de lanzamiento de martillo masculino es de $86.74$ metros y pertenece a Yuriy Sedykh desde 1986.
#
# El martillo masculino pesa $7.260 kg$, es esférico y tiene un radio típico $R = 6$ cm.
#
# El arrastre del martillo se puede considerar proporcional al cuadrado de la velocidad del martillo en relación con el aire:
# $$
# \begin{align*}
# F_{\text{D}} = \dfrac{1}{2} \, \rho \, A \, C_{\text{D}} \, v^{2}
# \end{align*}
# $$
# Donde:
# 1. $\rho$ es la densidad del aire $= 1.2 \, kg/m^{3}$
# 2. $A = \pi \, R^{2}$ es la sección de área del martillo.
#
# ## Tipos de flujo.
#
# El martillo puede experimentar, en principio, un flujo **laminar separado**, con un coeficiente de arrastre típico $C_{d} = 0.5$, o un flujo **inestable-oscilante**, con $C_{d} = 0.75$.

# %% [markdown]
# # Incisos a resolver.
#
# Considera los lanzamientos desde la posición inicial $x_{0} = 0$, $y_{0} = 2$ m, bajo el ángulo ideal $\varphi = 45^{\circ}$:
#
# 1. Encuentra la velocidad inicial que produce la distancia de lanzamiento del récord mundial.
# 2. Resuelve la ecuación de movimiento de Newton para el lanzamiento oblicuo del martillo usando el método predictor-corrector de Euler con un paso de tiempo $h = 0.01$, transformando primero las EDO para los movimientos $x$ e $y$ en un sistema de cuatro EDO1.
# 3. Calcula y grafica la dependencia temporal de la altitud del martillo y su trayectoria $y = y (x)$ en tres regímenes de flujo:
#     - Sin fricción.
#     - Flujo laminar separado.
#     - Flujo oscilante inestable.
#
# 4. Evalúa la cantidad por la cual la distancia de tiro está influenciada por el arrastre.

# %% [markdown]
# ## Inciso 1.
#
# Plantea el problema a partir de la información que nos da el enunciado y resuelve el correspondiente sistema, para demostrar que la velocidad inicial con la que se alcanza la distancia del lanzamiento que es récord mundial es:
#
# $$
# \begin{align*}
# v_{0} =  25 \text{m/s}
# \end{align*}
# $$

# %% [markdown]
# ## Inciso 2.
#
# El problema equivalente con el conjunto de EDO1 es el siguiente:
# $$
# \begin{align*}
# y_{1} &= x \\
# y_{2} &= y \\
# y_{3} &= v_{x} \\
# y_{4} &= v_{y} \\
# \end{align*}
# $$
#
# Se tiene entonces que:
# $$
# \begin{align*}
# \begin{bmatrix}
# y_{1}^{\prime} \\
# y_{2}^{\prime} \\
# y_{3}^{\prime} \\
# y_{4}^{\prime}
# \end{bmatrix}
# =
# \begin{bmatrix}
# y_{3} \\
# y_{4} \\
# - \bigg( \dfrac{k}{m} \bigg) \, y_{3} \, \left| y_{3} \right| \\
# - \bigg( \dfrac{k}{m} \bigg) \, y_{4} \, \left| y_{4} \right|
# \end{bmatrix}
# \hspace{1.5cm}
# \begin{bmatrix}
# y_{1} (0) \\
# y_{2} (0) \\
# y_{3} (0) \\
# y_{4} (0)
# \end{bmatrix}
# =
# \begin{bmatrix}
# x_{0} \\
# y_{0} \\
# v_{x0} \\
# v_{y0}
# \end{bmatrix}
# \end{align*}
# $$

# %%
# Aquí va la implementación del código que llama a la función eulerPC

# %% [markdown]
# Se muestra a continuación el resultado con el coeficiente $C_{D} = 0.5$, es decir, para el caso de **flujo laminar separado**.
#
# Gráfica para la distancia máxima alcanzada durante el lanzamiento del martillo.
#
# ![Solución para la distancia máxima](attachment:plot_eulerPC_ejercicio_02_01.png)

# %% [markdown]
# Gráfica para la altura máxima alcanzada durante el lanzamiento del martillo.
#
# ![Solución para la altura máxima](attachment:plot_eulerPC_ejercicio_02_02.png)
